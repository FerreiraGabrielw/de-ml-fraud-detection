# %% [markdown]
# # RDS Clean Databases
# Gabriel Ferreira

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import psycopg2
import pandas as pd
import os
from dotenv import load_dotenv

# %%
# ============================================================
# LOAD ENV
# ============================================================

load_dotenv("/home/jovyan/work/.env")

RDS_HOST = os.getenv("RDS_HOST")
RDS_PORT = os.getenv("RDS_PORT")
RDS_DATABASE = os.getenv("RDS_DATABASE")
RDS_USER = os.getenv("RDS_USER")
RDS_PASSWORD = os.getenv("RDS_PASSWORD")

# %%
conn = psycopg2.connect(
    host="fraud-detection-rds.cilk4oyi2c5j.us-east-1.rds.amazonaws.com",
    port="5432",
    database="fraud_analytics",
    user="postgres",
    password="fraud-gabriel-rds-2026"
)

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
# Validar fraud_predictions
query = """
SELECT COUNT(*)
FROM fraud_predictions;
"""

pd.read_sql(query, conn)
# Out:
# /tmp/ipykernel_4832/3482447501.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#      count
# 0  1336675

# %%
# Sample
query = """
SELECT *
FROM fraud_predictions
ORDER BY inference_timestamp DESC
LIMIT 20;
"""

pd.read_sql(query, conn)
# Out:
# /tmp/ipykernel_4832/1391123273.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#                                trans_num      amt  city_pop        lat  \
# 0   7609599b-6c08-44df-b312-ec2692c35ab9   259.23    116990  35.648352
# 1   fec3c38b-2b3d-487c-978b-67f5c1b382a2   299.77    974783  35.336268
# 2   fb02a824-3d31-4f18-9fcd-991881eb8a3f   263.33    284320  30.892875
# 3   fb93b2d2-3049-4d9f-b572-316808b81436   128.82      4547  36.286214
# 4   fdda06f0-ce4f-42cb-9421-93e5c4755f29    71.92    771750  37.642593
# 5   8a35cf20-a5c1-4426-bf03-624e42af16c5    46.95     45288  36.236825
# 6   fad57f5e-dace-483c-81e1-b763509bbaa1    31.99    244816  39.944753
# 7   89c64bb8-0d0d-4698-9999-82de9fb1704b   155.55    649728  37.797859
# 8   fb57cbc8-80cb-4d6e-94e3-6b97f7eea563   119.42    561041  34.191304
# 9   89d0244b-a0fe-4b28-b743-e1ec2e2b1398    18.81    907825  30.574312
# 10  fdd90fdc-e49c-4e3e-bf29-ba40da556904    14.45    290493  40.064979
# 11  89e3144b-c6c6-47cb-8799-6bef557b87a7   169.59     83101  43.926625
# 12  767b3e12-a353-459c-9263-204bdc95b6f2   260.20    204660  43.718946
# 13  fe9a4eb4-a41c-433f-ac7b-d4f422fd3a0c   234.65    885496  35.722211
# 14  fa226819-4199-4839-997f-5e3028d73d69   123.02    140884  42.352722
# 15  898bf89f-da0d-4553-9d30-00be20727f41   159.68    861932  40.035188
# 16  75e81ad3-d58b-423f-88c1-126db20d7ed1   243.85    626001  32.316452
# 17  fadf1555-167a-488b-a8a4-5851760baef7   282.25    942115  39.840309
# 18  7605c866-3a67-40d2-8cd4-d55e1ac654b2  5707.97     43414  33.711810
# 19  7689cf1a-eb34-488f-a80f-515eba2fea38   265.96    697175  33.917478
#
#          long  merch_lat  merch_long   unix_time  transaction_hour  \
# 0  -81.293576  35.642961  -81.328790  1778700801                16
# 1  -89.218425  35.321683  -89.263368  1778666940                 7
# 2  -94.582859  30.905323  -94.578914  1778622332                18
# 3  -82.499280  36.242350  -82.503554  1778650872                 2
