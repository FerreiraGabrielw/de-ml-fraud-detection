# %% [markdown]
# # RDS Clean Databases
# Gabriel Ferreira

# %%
from sqlalchemy import create_engine
from sqlalchemy import text

import os
from dotenv import load_dotenv


# ============================================================
# LOAD ENV
# ============================================================

load_dotenv("/home/jovyan/work/.env")

RDS_HOST = os.getenv("RDS_HOST")
RDS_PORT = os.getenv("RDS_PORT")
RDS_DATABASE = os.getenv("RDS_DATABASE")
RDS_USER = os.getenv("RDS_USER")
RDS_PASSWORD = os.getenv("RDS_PASSWORD")


# ============================================================
# RDS CONNECTION
# ============================================================

engine = create_engine(

    f"postgresql+psycopg2://{RDS_USER}:"
    f"{RDS_PASSWORD}@"
    f"{RDS_HOST}:{RDS_PORT}/"
    f"{RDS_DATABASE}"

)


# ============================================================
# DROPPING TABLES
# ============================================================

with engine.connect() as conn:

    conn.execute(
        text("DROP TABLE IF EXISTS fraud_predictions")
    )

    conn.execute(
        text("DROP TABLE IF EXISTS fraud_transactions_full")
    )

    conn.commit()


print("RDS tables successfully dropped.")
# Out:
# RDS tables successfully dropped.
